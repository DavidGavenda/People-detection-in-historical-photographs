# %%
# !nvidia-smi
# Out:
# Thu Apr 20 18:28:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.33       Driver Version: 528.33       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:06:00.0  On |                  N/A |
# | 44%   38C    P8    15W / 200W |    386MiB /  8192MiB |      3%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Load and configure TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir runs/detect --port=6005
# Out:
# Reusing TensorBoard on port 6005 (pid 13860), started 14:20:23 ago. (Use '!kill 13860' to kill it.)
#       <iframe id="tensorboard-frame-e6f76aad6b7680a0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e6f76aad6b7680a0");
#           const url = new URL("/", window.location);
#           const port = 6005;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import time
import torch
import pandas as pd
import gc

from ultralytics import YOLO


modelname = 'SGD' + '_default_'

if __name__ == '__main__':    
    model = YOLO('yolov8l')
        
    # Enable cuDNN benchmark mode
    # torch.backends.cudnn.benchmark = True
    
    results = model.train(
        data='data_custom-COCO-CycleGAN.yaml',
        imgsz=640,
        epochs=200,
        device=0,
        batch=12,  # na 4 ked budes mat ssh 8 pre 640
        plots=True,
        iou=0.5,
        patience=25,
        single_cls=True,
        # optimizer='Adam',
        # lr0=0.02,
        name=modelname,
        half=True  # Enable mixed precision training
    )

    # Clean cache and free memory
    del model
    del results
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# New https://pypi.org/project/ultralytics/8.0.83 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.54  Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191MiB)
# ...

# %%
import time
import torch
import pandas as pd
import gc

from ultralytics import YOLO


modelname = 'SGD' + '_default_COCOadjusted_'

if __name__ == '__main__':    
    model = YOLO('yolov8l')
        
    # Enable cuDNN benchmark mode
    # torch.backends.cudnn.benchmark = True
    
    results = model.train(
        data='data_custom-COCO.yaml',
        imgsz=640,
        epochs=200,
        device=0,
        batch=12,  # na 4 ked budes mat ssh 8 pre 640
        plots=True,
        iou=0.5,
        patience=25,
        single_cls=True,
        # optimizer='Adam',
        # lr0=0.02,
        name=modelname,
        half=True  # Enable mixed precision training
    )

    # Clean cache and free memory
    del model
    del results
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# New https://pypi.org/project/ultralytics/8.0.89 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.54  Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191MiB)
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/detect --port=6004
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-6d8b53c1953a1372" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6d8b53c1953a1372");
#           const url = new URL("/", window.location);
#           const port = 6004;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import os 
from ultralytics import YOLO

from torch.utils.tensorboard import SummaryWriter

# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='runs/detect/', histogram_freq=1)

if __name__ == '__main__':
    tb_writer = SummaryWriter()
    model = YOLO('yolov8x')
    model.train(
        data = 'data_custom.yaml',
        imgsz = 640,  #na 1280 ked budes mat ssh
        epochs = 250, 
        device = 0, 
        batch = 4, #na 4 ked budes mat ssh 8 pre 640
        plots = True,
        iou = 0.5,
        patience= 25,
        optimizer = 'Adam',
        single_cls = True,
        name = 'Adam_YoloV8x'
        )
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# Ultralytics YOLOv8.0.54  Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191MiB)
# ...
